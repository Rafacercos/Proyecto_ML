# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../Data/Processed/Datos.csv',index_col=0)

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(numeric_only=True),annot=True,vmin=-1,cmap="coolwarm")
# Out:
# <Axes: >
